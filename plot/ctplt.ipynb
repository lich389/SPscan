# %%
import sys
import contourplt as fplt
import matplotlib.pyplot as plt
import numpy as np

r1 = (213/255,105/255,93/255)
o1 = (245/255,176/255,65/255)
y1= (246/255,218/255,101/255)
g1=(82/255,190/255,128/255)
c1=(145/255,223/255,208/255)
b1=(93/255,173/255,226/255)
p1=(164/255,105/255,189/255)
br1=(138/255,112/255,103/255)
pk1=(255/255,188/255,167/255)
b2=(72/255,79/255,152/255)
y2=(255/255,255/255,133/255)

# %% [markdown]
# # $t_b$ vs $m_A$

# %% [markdown]
# #### $\alpha_{AS}$

# %%
fig, ax = plt.subplots(1, 1)
cntplt = fplt.cntplt(
    50, 50,
    '../build/',
    'tbma',
    'ma1',
    'tb',
)

cntplt.get_inp_comb(['flavorcheck'])
cntplt.reshape()
# cntplt.contline(ax,'tab:grey',ls='dotted')
# cntplt.contcolor(ax,'tab:grey',alp=0.1)
cntplt.plt_hatchline(ax,'')
ax.text(800, 3, 'Flavor', rotation=-90, color='grey', alpha=0.7)

cntplt.get_inp_comb(['r36tttt', 'r35tttt'])
cntplt.cut(cut={'x':[],'y':[]})
cntplt.reshape()
cntplt.contline(ax,'tab:orange',ls='-')
cntplt.contcolor(ax,'tab:orange',alp=0.3)

cntplt.get_inp_comb(['r36tt', 'r35tt'])
cntplt.cut(cut={'x':[],'y':[]})
cntplt.reshape()
cntplt.contline(ax,'tab:green')
cntplt.contcolor(ax,'tab:green',alp=0.3)


cntplt.get_inp_comb(['r36gamgam', 'r35gamgam'])
cntplt.reshape()
cntplt.contline(ax,'tab:blue')
cntplt.contcolor(ax,'tab:blue',alp=0.3)


cntplt.get_inp_comb(['r35tautau','r36tautau'])
cntplt.cut(cut={'x':[],'y':[]},both=False)
cntplt.reshape()
cntplt.contline(ax,'tab:pink')
cntplt.contcolor(ax,'tab:pink',alp=0.3)

cntplt.get_inp_comb(['r35bb','r36bb'])
cntplt.cut(cut={'x':[],'y':[]},both=False)
cntplt.reshape()
cntplt.contline(ax,'tab:purple')
cntplt.contcolor(ax,'tab:purple',alp=0.3)

cntplt2 = fplt.cntplt(
    50, 50,
    '../build/',
    'tbma_a4',
    'ma1',
    'tb',
)

cntplt2.printidx()
# cntplt2.get_inp_comb(['flavorcheck'])
# cntplt2.reshape()
# cntplt2.contline(ax,'tab:grey',ls='dotted')
# cntplt2.contcolor(ax,'tab:grey',alp=0.1)
cntplt2.get_inp_comb(['STUcheck'])
cntplt2.cut(cut={'x':[],'y':[]},both=False)
cntplt2.reshape()
cntplt2.contline(ax,'tab:brown',ls='--')
cntplt2.contcolor(ax,'tab:brown',alp=0.1)
ax.text(230, 1, 'STU', rotation=-90, color='tab:brown', alpha=0.7)

cntplt2.get_inp_comb(['r36tttt', 'r35tttt'])
cntplt2.cut(cut={'x':[],'y':[]})
cntplt2.reshape()
cntplt2.contline(ax,'tab:orange',ls='--')
cntplt2.contcolor(ax,'tab:orange',alp=0.1)

cntplt2.get_inp_comb(['r35tautau','r36tautau'])
cntplt2.cut(cut={'x':[],'y':[]},both=False)
cntplt2.reshape()
cntplt2.contline(ax,'tab:pink',ls='--')
cntplt2.contcolor(ax,'tab:pink',alp=0.1)

cntplt2.get_inp_comb(['r35bb','r36bb'])
cntplt2.cut(cut={'x':[],'y':[]},both=False)
cntplt2.reshape()
cntplt2.contline(ax,'tab:purple',ls='--')
cntplt2.contcolor(ax,'tab:purple',alp=0.1)

cntplt2.get_inp_comb(['r36gamgam', 'r35gamgam'])
cntplt2.reshape()
cntplt2.contline(ax,'tab:blue', ls='--')
cntplt2.contcolor(ax,'tab:blue',alp=0.1)

cntplt2.get_inp_comb(['r36tt', 'r35tt'])
cntplt2.cut(cut={'x':[],'y':[]})
cntplt2.reshape()
cntplt2.contline(ax,'tab:green',ls='--')
cntplt2.contcolor(ax,'tab:green',alp=0.1)

ax.text(550, 0.65, r'$H/A\rightarrow tt$', rotation=0, color='tab:green', alpha=1)
ax.text(550, 1, r'$ttH/A\rightarrow tttt$', rotation=-10, color='tab:orange', alpha=1)
ax.text(240, 2, r'$H/A\rightarrow \gamma\gamma$', rotation=20, color='tab:blue', alpha=1)
ax.text(650, 10, r'$H/A\rightarrow bb$', rotation=0, color='tab:purple', alpha=1)
ax.text(500, 5, r'$H/A\rightarrow \tau\tau$', rotation=0, color='tab:pink', alpha=1)

# ax.legend(cntplt.lst_lab)
# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$m_{A}=m_H=m_{H^\pm}$ [GeV]')
ax.set_ylabel(r'$\tan\beta$')

import matplotlib.lines as mlines
solid_line = mlines.Line2D([], [], color='black', linestyle='-', label=r'$\alpha_{AS}=0$')
dashed_line = mlines.Line2D([], [], color='black', linestyle='--', label=r'$\alpha_{AS}=\pi/4$')
plt.legend(handles=[solid_line, dashed_line], loc='lower right')

plt.savefig('2HDMS_tb_ma_a4.png', dpi=300)
# Out:
# ['Unnamed: 0', 'tb', 'vs', 'mh1', 'mh2', 'mh3', 'ma1', 'ma2', 'mhp', 'mutild', 'r35bb', 'r36bb', 'r25tautau', 'r35tautau', 'r36tautau', 'r25gamgam', 'r35gamgam', 'r36gamgam', 'STUFit', 'STUcheck', 'b->sgamma', 'bs->mumu', 'delmbs', 'bsgcheck', 'bsmmcheck', 'mbscheck', 'flavorcheck', 'r35tttt', 'r36tttt', 'r35tt', 'r36tt']

# %% [markdown]
# #### $\alpha_{HS}$

# %%
fig, ax = plt.subplots(1, 1)
cntplt = fplt.cntplt(
    50, 50,
    '../build/',
    'tbma',
    'ma1',
    'tb',
)

cntplt.get_inp_comb(['flavorcheck'])
cntplt.reshape()
# cntplt.contline(ax,'tab:grey',ls='dotted')
# cntplt.contcolor(ax,'tab:grey',alp=0.1)
cntplt.plt_hatchline(ax,'')
ax.text(800, 3, 'Flavor', rotation=-90, color='grey', alpha=0.7)


cntplt.get_inp_comb(['r36tttt', 'r35tttt'])
cntplt.cut(cut={'x':[],'y':[]})
cntplt.reshape()
cntplt.contline(ax,'tab:orange',ls='-')
cntplt.contcolor(ax,'tab:orange',alp=0.3)

cntplt.get_inp_comb(['r36tt', 'r35tt'])
cntplt.cut(cut={'x':[],'y':[]})
cntplt.reshape()
cntplt.contline(ax,'tab:green')
cntplt.contcolor(ax,'tab:green',alp=0.3)


cntplt.get_inp_comb(['r36gamgam', 'r35gamgam'])
cntplt.reshape()
cntplt.contline(ax,'tab:blue')
cntplt.contcolor(ax,'tab:blue',alp=0.3)


cntplt.get_inp_comb(['r35tautau','r36tautau'])
cntplt.cut(cut={'x':[],'y':[]},both=False)
cntplt.reshape()
cntplt.contline(ax,'tab:pink')
cntplt.contcolor(ax,'tab:pink',alp=0.3)

cntplt.get_inp_comb(['r35bb','r36bb'])
cntplt.cut(cut={'x':[],'y':[]},both=False)
cntplt.reshape()
cntplt.contline(ax,'tab:purple')
cntplt.contcolor(ax,'tab:purple',alp=0.3)

cntplt2 = fplt.cntplt(
    50, 50,
    '../build/',
    'tbma_a2',
    'ma1',
    'tb',
)

cntplt2.printidx()
# cntplt2.get_inp_comb(['flavorcheck'])
# cntplt2.reshape()
# cntplt2.contline(ax,'tab:grey',ls='dotted')
# cntplt2.contcolor(ax,'tab:grey',alp=0.1)
cntplt2.get_inp_comb(['STUcheck'])
cntplt2.cut(cut={'x':[],'y':[]},both=False)
cntplt2.reshape()
cntplt2.contline(ax,'tab:brown',ls='--')
cntplt2.contcolor(ax,'tab:brown',alp=0.1)
ax.text(230, 1, 'STU', rotation=-90, color='tab:brown', alpha=0.7)

cntplt2.get_inp_comb(['r36tttt', 'r35tttt'])
cntplt2.cut(cut={'x':[],'y':[]})
cntplt2.reshape()
cntplt2.contline(ax,'tab:orange',ls='--')
cntplt2.contcolor(ax,'tab:orange',alp=0.1)

cntplt2.get_inp_comb(['r35tautau','r36tautau'])
cntplt2.cut(cut={'x':[],'y':[]},both=False)
cntplt2.reshape()
cntplt2.contline(ax,'tab:pink',ls='--')
cntplt2.contcolor(ax,'tab:pink',alp=0.1)

cntplt2.get_inp_comb(['r35bb','r36bb'])
cntplt2.cut(cut={'x':[],'y':[]},both=False)
cntplt2.reshape()
cntplt2.contline(ax,'tab:purple',ls='--')
cntplt2.contcolor(ax,'tab:purple',alp=0.1)

cntplt2.get_inp_comb(['r36gamgam', 'r35gamgam'])
cntplt2.reshape()
cntplt2.contline(ax,'tab:blue', ls='--')
cntplt2.contcolor(ax,'tab:blue',alp=0.1)

cntplt2.get_inp_comb(['r36tt', 'r35tt'])
cntplt2.cut(cut={'x':[],'y':[]})
cntplt2.reshape()
cntplt2.contline(ax,'tab:green',ls='--')
cntplt2.contcolor(ax,'tab:green',alp=0.1)

ax.text(550, 0.65, r'$H/A\rightarrow tt$', rotation=0, color='tab:green', alpha=1)
ax.text(550, 1, r'$ttH/A\rightarrow tttt$', rotation=-10, color='tab:orange', alpha=1)
ax.text(240, 2, r'$H/A\rightarrow \gamma\gamma$', rotation=20, color='tab:blue', alpha=1)
ax.text(650, 10, r'$H/A\rightarrow bb$', rotation=0, color='tab:purple', alpha=1)
ax.text(500, 5, r'$H/A\rightarrow \tau\tau$', rotation=0, color='tab:pink', alpha=1)

# ax.legend(cntplt.lst_lab)
# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$m_{A}=m_H=m_{H^\pm}$ [GeV]')
ax.set_ylabel(r'$\tan\beta$')

import matplotlib.lines as mlines
solid_line = mlines.Line2D([], [], color='black', linestyle='-', label=r'$\alpha_{HS}=0$')
dashed_line = mlines.Line2D([], [], color='black', linestyle='--', label=r'$\alpha_{HS}=\pi/4$')
plt.legend(handles=[solid_line, dashed_line], loc='lower right')

plt.savefig('2HDMS_tb_ma_a2.png', dpi=300)
# Out:
# ['Unnamed: 0', 'tb', 'vs', 'mh1', 'mh2', 'mh3', 'ma1', 'ma2', 'mhp', 'mutild', 'r35bb', 'r36bb', 'r25tautau', 'r35tautau', 'r36tautau', 'r35gamgam', 'r36gamgam', 'STUFit', 'STUcheck', 'b->sgamma', 'bs->mumu', 'delmbs', 'bsgcheck', 'bsmmcheck', 'mbscheck', 'flavorcheck', 'r35tttt', 'r36tttt', 'r35tt', 'r36tt']

# %% [markdown]
# #### $\alpha_{hS}$

# %%
fig, ax = plt.subplots(1, 1)
cntplt = fplt.cntplt(
    50, 50,
    '../build/',
    'tbma',
    'ma1',
    'tb',
)

cntplt.get_inp_comb(['flavorcheck'])
cntplt.reshape()
# cntplt.contline(ax,'tab:grey',ls='dotted')
# cntplt.contcolor(ax,'tab:grey',alp=0.1)
cntplt.plt_hatchline(ax,'')
ax.text(800, 3, 'Flavor', rotation=-90, color='grey', alpha=0.7)


cntplt.get_inp_comb(['r36tttt', 'r35tttt'])
cntplt.cut(cut={'x':[],'y':[]})
cntplt.reshape()
cntplt.contline(ax,'tab:orange',ls='-')
cntplt.contcolor(ax,'tab:orange',alp=0.3)

cntplt.get_inp_comb(['r36tt', 'r35tt'])
cntplt.cut(cut={'x':[],'y':[]})
cntplt.reshape()
cntplt.contline(ax,'tab:green')
cntplt.contcolor(ax,'tab:green',alp=0.3)


cntplt.get_inp_comb(['r36gamgam', 'r35gamgam'])
cntplt.reshape()
cntplt.contline(ax,'tab:blue')
cntplt.contcolor(ax,'tab:blue',alp=0.3)


cntplt.get_inp_comb(['r35tautau','r36tautau'])
cntplt.cut(cut={'x':[],'y':[]},both=False)
cntplt.reshape()
cntplt.contline(ax,'tab:pink')
cntplt.contcolor(ax,'tab:pink',alp=0.3)

cntplt.get_inp_comb(['r35bb','r36bb'])
cntplt.cut(cut={'x':[],'y':[]},both=False)
cntplt.reshape()
cntplt.contline(ax,'tab:purple')
cntplt.contcolor(ax,'tab:purple',alp=0.3)

cntplt2 = fplt.cntplt(
    50, 50,
    '../build/',
    'tbma_a3',
    'ma1',
    'tb',
)

cntplt2.printidx()
# cntplt2.get_inp_comb(['flavorcheck'])
# cntplt2.reshape()
# cntplt2.contline(ax,'tab:grey',ls='dotted')
# cntplt2.contcolor(ax,'tab:grey',alp=0.1)
cntplt2.get_inp_comb(['STUcheck'])
cntplt2.cut(cut={'x':[],'y':[]},both=False)
cntplt2.reshape()
cntplt2.contline(ax,'tab:brown',ls='--')
cntplt2.contcolor(ax,'tab:brown',alp=0.1)
# ax.text(230, 1, 'STU', rotation=-90, color='tab:brown', alpha=0.7)
cntplt2.get_inp_comb(['hscheck'])
cntplt2.cut(cut={'x':[],'y':[]},both=False)
cntplt2.reshape()
cntplt2.contline(ax,'tab:brown',ls='--')
cntplt2.contcolor(ax,'tab:brown',alp=1)

cntplt2.get_inp_comb(['r36tttt', 'r35tttt'])
cntplt2.cut(cut={'x':[],'y':[]})
cntplt2.reshape()
cntplt2.contline(ax,'tab:orange',ls='--')
cntplt2.contcolor(ax,'tab:orange',alp=0.1)

cntplt2.get_inp_comb(['r35tautau','r36tautau'])
cntplt2.cut(cut={'x':[],'y':[]},both=False)
cntplt2.reshape()
cntplt2.contline(ax,'tab:pink',ls='--')
cntplt2.contcolor(ax,'tab:pink',alp=0.1)

cntplt2.get_inp_comb(['r35bb','r36bb'])
cntplt2.cut(cut={'x':[],'y':[]},both=False)
cntplt2.reshape()
cntplt2.contline(ax,'tab:purple',ls='--')
cntplt2.contcolor(ax,'tab:purple',alp=0.1)

cntplt2.get_inp_comb(['r36gamgam', 'r35gamgam'])
cntplt2.reshape()
cntplt2.contline(ax,'tab:blue', ls='--')
cntplt2.contcolor(ax,'tab:blue',alp=0.1)

cntplt2.get_inp_comb(['r36tt', 'r35tt'])
cntplt2.cut(cut={'x':[],'y':[]})
cntplt2.reshape()
cntplt2.contline(ax,'tab:green',ls='--')
cntplt2.contcolor(ax,'tab:green',alp=0.1)

cntplt2.get_inp_comb(['r45VV'])
cntplt2.cut(cut={'x':[],'y':[]})
cntplt2.reshape()
cntplt2.contline(ax,'y',ls='--')
cntplt2.contcolor(ax,'y',alp=0.1)
ax.text(730, 1, r'$h_S \rightarrow VV$', rotation=90, color='y', alpha=1)

ax.text(550, 0.65, r'$H/A\rightarrow tt$', rotation=0, color='tab:green', alpha=1)
ax.text(550, 1, r'$ttH/A\rightarrow tttt$', rotation=-10, color='tab:orange', alpha=1)
ax.text(240, 2, r'$H/A\rightarrow \gamma\gamma$', rotation=20, color='tab:blue', alpha=1)
ax.text(650, 10, r'$H/A\rightarrow bb$', rotation=0, color='tab:purple', alpha=1)
ax.text(500, 5, r'$H/A\rightarrow \tau\tau$', rotation=0, color='tab:pink', alpha=1)

# ax.legend(cntplt.lst_lab)
# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$m_{A}=m_H=m_{H^\pm}$ [GeV]')
ax.set_ylabel(r'$\tan\beta$')

import matplotlib.lines as mlines
solid_line = mlines.Line2D([], [], color='black', linestyle='-', label=r'$\alpha_{hS}=0$')
dashed_line = mlines.Line2D([], [], color='black', linestyle='--', label=r'$\alpha_{hS}=0.25$')
plt.legend(handles=[solid_line, dashed_line], loc='lower right')

plt.savefig('2HDMS_tb_ma_a3.png', dpi=300)
# Out:
# ['Unnamed: 0', 'tb', 'vs', 'mh1', 'mh2', 'mh3', 'ma1', 'ma2', 'mhp', 'mutild', 'r45VV', 'r35bb', 'r36bb', 'r25tautau', 'r35tautau', 'r36tautau', 'r35gamgam', 'r36gamgam', 'delchi2', 'STUFit', 'b->sgamma', 'bs->mumu', 'delmbs', 'bsgcheck', 'bsmmcheck', 'mbscheck', 'flavorcheck', 'r35tttt', 'r36tttt', 'r35tt', 'r36tt']

# %% [markdown]
# #### $c_{\beta-\alpha}$

# %%
fig, ax = plt.subplots(1, 1)
cntplt = fplt.cntplt(
    50, 50,
    '../build/',
    'tbma',
    'ma1',
    'tb',
)

cntplt.get_inp_comb(['flavorcheck'])
cntplt.reshape()
# cntplt.contline(ax,'tab:grey',ls='dotted')
# cntplt.contcolor(ax,'tab:grey',alp=0.1)
cntplt.plt_hatchline(ax,'')
ax.text(800, 3, 'Flavor', rotation=-90, color='grey', alpha=0.7)


cntplt.get_inp_comb(['r36tttt', 'r35tttt'])
cntplt.cut(cut={'x':[],'y':[]})
cntplt.reshape()
cntplt.contline(ax,'tab:orange',ls='-')
cntplt.contcolor(ax,'tab:orange',alp=0.3)

cntplt.get_inp_comb(['r36tt', 'r35tt'])
cntplt.cut(cut={'x':[],'y':[]})
cntplt.reshape()
cntplt.contline(ax,'tab:green')
cntplt.contcolor(ax,'tab:green',alp=0.3)


cntplt.get_inp_comb(['r36gamgam', 'r35gamgam'])
cntplt.reshape()
cntplt.contline(ax,'tab:blue')
cntplt.contcolor(ax,'tab:blue',alp=0.2)


cntplt.get_inp_comb(['r35tautau','r36tautau'])
cntplt.cut(cut={'x':[],'y':[]},both=False)
cntplt.reshape()
cntplt.contline(ax,'tab:pink')
cntplt.contcolor(ax,'tab:pink',alp=0.3)

cntplt.get_inp_comb(['r35bb','r36bb'])
cntplt.cut(cut={'x':[],'y':[]},both=False)
cntplt.reshape()
cntplt.contline(ax,'tab:purple')
cntplt.contcolor(ax,'tab:purple',alp=0.3)

cntplt2 = fplt.cntplt(
    50, 50,
    '../build/',
    '',
    'ma1',
    'tb',
)

cntplt2.printidx()
# cntplt2.get_inp_comb(['flavorcheck'])
# cntplt2.reshape()
# cntplt2.contline(ax,'tab:grey',ls='dotted')
# cntplt2.contcolor(ax,'tab:grey',alp=0.1)
cntplt2.get_inp_comb(['STUcheck'])
cntplt2.cut(cut={'x':[],'y':[]},both=False)
cntplt2.reshape()
cntplt2.contline(ax,'tab:brown',ls='--')
cntplt2.contcolor(ax,'tab:brown',alp=0.1)
cntplt2.get_inp_comb(['hscheck'])
cntplt2.cut(cut={'x':[],'y':[]},both=False)
cntplt2.reshape()
cntplt2.contline(ax,'tab:cyan',ls='--')
cntplt2.contcolor(ax,'tab:cyan',alp=0.1)
ax.text(900, 4.5, '$h_{125}$', rotation=0, color='tab:cyan', alpha=1)
ax.text(900, 0.35, '$h_{125}$', rotation=0, color='tab:cyan', alpha=1)

cntplt2.get_inp_comb(['r36tttt', 'r35tttt'])
cntplt2.cut(cut={'x':[],'y':[]})
cntplt2.reshape()
cntplt2.contline(ax,'tab:orange',ls='--')
cntplt2.contcolor(ax,'tab:orange',alp=0.1)

cntplt2.get_inp_comb(['r35tautau','r36tautau'])
cntplt2.cut(cut={'x':[],'y':[]},both=False)
cntplt2.reshape()
cntplt2.contline(ax,'tab:pink',ls='--')
cntplt2.contcolor(ax,'tab:pink',alp=0.1)

cntplt2.get_inp_comb(['r35bb','r36bb'])
cntplt2.cut(cut={'x':[],'y':[]},both=False)
cntplt2.reshape()
cntplt2.contline(ax,'tab:purple',ls='--')
cntplt2.contcolor(ax,'tab:purple',alp=0.1)

cntplt2.get_inp_comb(['r36gamgam', 'r35gamgam'])
cntplt2.reshape()
cntplt2.contline(ax,'tab:blue', ls='--')
cntplt2.contcolor(ax,'tab:blue',alp=0.1)

cntplt2.get_inp_comb(['r36tt', 'r35tt'])
cntplt2.cut(cut={'x':[],'y':[]})
cntplt2.reshape()
cntplt2.contline(ax,'tab:green',ls='--')
cntplt2.contcolor(ax,'tab:green',alp=0.1)

cntplt2.get_inp_comb(['r35VV'])
cntplt2.cut(cut={'x':[],'y':[]})
cntplt2.reshape()
cntplt2.contline(ax,'g',ls='--')
cntplt2.contcolor(ax,'g',alp=0.1)
ax.text(250, 2.5, r'$H\rightarrow VV$', rotation=20, color='g', alpha=1)


cntplt2.get_inp_comb(['r35HH'])
cntplt2.cut(cut={'x':[],'y':[]})
cntplt2.reshape()
cntplt2.contline(ax,'tab:red',ls='--')
cntplt2.contcolor(ax,'tab:red',alp=0.1)
ax.text(420, 0.5, r'$H\rightarrow hh$', rotation=-90, color='tab:red', alpha=1)

ax.text(550, 0.65, r'$H/A\rightarrow tt$', rotation=0, color='tab:green', alpha=1)
ax.text(550, 1, r'$ttH/A\rightarrow tttt$', rotation=-10, color='tab:orange', alpha=1)
ax.text(150, 1.6, r'$H/A\rightarrow \gamma\gamma$', rotation=20, color='tab:blue', alpha=1)
ax.text(650, 10, r'$H/A\rightarrow bb$', rotation=0, color='tab:purple', alpha=1)
ax.text(500, 5, r'$H/A\rightarrow \tau\tau$', rotation=0, color='tab:pink', alpha=1)

# ax.legend(cntplt.lst_lab)
# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel(r'$m_{A}=m_H=m_{H^\pm}$ [GeV]')
ax.set_ylabel(r'$\tan\beta$')

import matplotlib.lines as mlines
solid_line = mlines.Line2D([], [], color='black', linestyle='-', label=r'$c_{\beta-\alpha}=0$')
dashed_line = mlines.Line2D([], [], color='black', linestyle='--', label=r'$c_{\beta-\alpha}=0.025$')
plt.legend(handles=[solid_line, dashed_line], loc='lower right')

plt.savefig('2HDMS_tb_ma_a1.png', dpi=300)
# Out:
# ['Unnamed: 0', 'tb', 'vs', 'mh1', 'mh2', 'mh3', 'ma1', 'ma2', 'mhp', 'mutild', 'r25VV', 'r35VV', 'r35bb', 'r36bb', 'r25tautau', 'r35tautau', 'r36tautau', 'r35gamgam', 'r36gamgam', 'delchi2', 'hscheck', 'STUFit', 'b->sgamma', 'bs->mumu', 'delmbs', 'bsgcheck', 'bsmmcheck', 'mbscheck', 'flavorcheck', 'r25ZH', 'r36ZH', 'r25HH', 'r35HH', 'r35tttt', 'r36tttt', 'r25gamgam', 'r35tt', 'r36tt']

# %% [markdown]
# # $\alpha$ vs $m$

# %% [markdown]
# ##### $\alpha_{hs}$ vs $m_{hs}$

# %%
fig, ax = plt.subplots(1, 1)
cntplt = fplt.cntplt(
    51, 100,
    '../build/',
    'mhsa3',
    'mh3',
    'a23',
)
cntpltlow = fplt.cntplt(
    51, 30,
    '../build/',
    'mhsa3low',
    'mh3',
    'a23',
)
# cntplthigh = fplt.cntplt(
#     50, 50,
#     '../build/',
#     'mhsa3high',
#     'mh3',
#     'a23',
# )

cntplt.printidx()
# cntplthigh.printidx()
cntpltlow.printidx()
cntplt.get_inp_comb(['hscheck'])
cntplt.apdcomb(cntpltlow,'hscheck')
# cntplt.reshape()
cntplt.contcolor(ax,color=c1,alp=0.5)
cntplt.contline(ax,c1,ls='-',lw=0.5)
ax.text(120, 0.25, '$h_{125}$', rotation=0, color=c1, alpha=1)
ax.text(120, -0.3, '$h_{125}$', rotation=0, color=c1, alpha=1)

cntplt.get_inp_comb(['STUcheck'])
cntplt.apdcomb(cntpltlow,'STUcheck')
# cntplt.reshape()
cntplt.contcolor(ax,color='tab:grey',alp=0.3)
cntplt.contline(ax,'tab:grey',ls='-',lw=0.5)
ax.text(400, 0.4, '$STU$', rotation=-20, color='tab:grey', alpha=1)
ax.text(400, -0.5, '$STU$', rotation=20, color='tab:grey', alpha=1)



cntplt.get_inp_comb(['r35VV','r45VV'])
cntplt.cut(cut={'x':[120,135],'y':[]})
# cntplt.apdcomb(cntpltlow,'r25VV')
# cntplt.apdcomb(cntplthigh,'r45VV')
cntplt.reshape()
cntplt.contcolor(ax,color=r1)
cntplt.contline(ax,r1,ls='-',lw=0.5)
ax.text(240, 0.05, r'$h_{S}\rightarrow VV$', rotation=-20, color='tab:red', alpha=1)
ax.text(170, -0.15, r'$h_{S}\rightarrow VV$', rotation=0, color='tab:red', alpha=1)



cntplt.get_inp_comb(['r35HH','r45HH'])
cntplt.reshape()
cntplt.contcolor(ax,color=b1)
cntplt.contline(ax,b1,ls='-',lw=0.5)
ax.text(240, 0.25, r'$h_{S}\rightarrow h h$', rotation=30, color='tab:blue', alpha=1)
ax.text(350, -0.15, r'$h_{S}\rightarrow h h$', rotation=10, color='tab:blue', alpha=1)

cntpltlow.get_inp_comb(['r25HH'])
cntpltlow.reshape()
cntpltlow.contcolor(ax,color=g1)
cntpltlow.contline(ax,g1,ls='-',lw=1)
ax.text(35, 0.05, r'$h\rightarrow h_S h_S$', rotation=-00, color='tab:green', alpha=1)


cntplt.get_inp_comb(['r35gamgam'])
cntplt.apdcomb(cntpltlow,'r25gamgam')
# cntplt.reshape()
cntplt.contcolor(ax,color=br1)
cntplt.contline(ax,br1,ls='-',lw=0.5)
ax.text(70, 0.05, r'$h_{S}\rightarrow \gamma\gamma$', rotation=-30, color='tab:brown', alpha=1)
ax.text(70, -0.15, r'$h_{S}\rightarrow \gamma\gamma$', rotation=30, color='tab:brown', alpha=1)


cntpltlow.get_inp_comb(['r25bb'])
cntpltlow.reshape()
cntpltlow.contcolor(ax,color=p1)
cntpltlow.contline(ax,p1,ls='-',lw=0.5)
ax.text(25, 0.1, r'$h_{S}\rightarrow b b$', rotation=-0, color='tab:purple', alpha=1)
ax.text(25, -0.12, r'$h_{S}\rightarrow b b$', rotation=0, color='tab:purple', alpha=1)

cntpltlow.get_inp_comb(['r25jj'])
cntpltlow.reshape()
cntpltlow.contcolor(ax,color='tab:orange',alp=0.3)
cntpltlow.contline(ax,o1,ls='-',lw=0.5)
ax.text(25, 0.25, r'$h_{S}\rightarrow j j$', rotation=-0, color='tab:orange', alpha=1)
ax.text(25, -0.27, r'$h_{S}\rightarrow j j$', rotation=0, color='tab:orange', alpha=1)
cntpltlow.get_inp_comb(['r25tautau'])
cntpltlow.reshape()
# cntplt.apdcomb(cntpltlow,'r25tautau')
cntpltlow.contcolor(ax,color='tab:olive')
cntpltlow.contline(ax,y1,ls='-',lw=0.5)

ax.text(30, 0.5, r'$h_{S}\rightarrow \tau\tau$', rotation=-30, color='tab:olive', alpha=1)
ax.text(30, -0.65, r'$h_{S}\rightarrow \tau\tau$', rotation=30, color='tab:olive', alpha=1)


ax.set_xscale('log')

ax.set_ylabel(r'$\alpha_{hS}$')
ax.set_xlabel(r'$m_{h_S}$ [GeV]')


plt.tight_layout()
plt.savefig('mhsa3.png', dpi=300)
# Out:
# ['Unnamed: 0', 'vs', 'mh1', 'mh2', 'mh3', 'ma1', 'ma2', 'mhp', 'mutild', 'rs25', 'rs35', 'rs45', 'r25VV', 'r35VV', 'delchi2', 'hscheck', 'STUFit', 'STUcheck', 'b->sgamma', 'bs->mumu', 'delmbs', 'bsgcheck', 'bsmmcheck', 'mbscheck', 'flavorcheck', 'r25HH', 'r35HH', 'r45VV', 'r45HH']
# ['Unnamed: 0', 'vs', 'mh1', 'mh2', 'mh3', 'ma1', 'ma2', 'mhp', 'mutild', 'rs25', 'rs35', 'r25tautau', 'r25HH', 'r35HH', 'delchi2', 'hscheck', 'STUFit', 'STUcheck', 'b->sgamma', 'bs->mumu', 'delmbs', 'bsgcheck', 'bsmmcheck', 'mbscheck', 'flavorcheck', 'r25bb', 'r25gamgam', 'r25jj', 'r35VV', 'r35bb', 'r25VV']

# %% [markdown]
# #### $\alpha_{HS}$ vs $m_{hS}$

# %%
fig, ax = plt.subplots(1, 1)
cntplt = fplt.cntplt(
    51, 50,
    '../build/',
    'mhsa2',
    'mh3',
    'a13',
)
cntpltlow = fplt.cntplt(
    51, 50,
    '../build/',
    'mhsa2low',
    'mh3',
    'a13',
)


cntplt.printidx()
# cntplthigh.printidx()
cntpltlow.printidx()



cntplt.get_inp_comb(['r45HH'])
# cntplt.reshape()
cntplt.apdcomb(cntpltlow,'r45HH')
cntplt.contcolor(ax,color='tab:orange')
cntplt.contline(ax,o1,ls='-',lw=1)

ax.text(65, 0.15, r'$H\rightarrow h_S h$', rotation=-40, color='tab:orange', alpha=1)
ax.text(65, -0.3, r'$H\rightarrow h_S h$', rotation=40, color='tab:orange', alpha=1)


cntplt.get_inp_comb(['r36ZH'])
cntplt.apdcomb(cntpltlow,'r36ZH')
cntplt.contcolor(ax,color='tab:blue')
cntplt.contline(ax,'tab:blue',ls='-',lw=1)


ax.text(300, 0.15, r'$A\rightarrow h_S Z$', rotation=60, color='tab:blue', alpha=1)
ax.text(300, -0.3, r'$A\rightarrow h_S Z$', rotation=-60, color='tab:blue', alpha=1)

cntplt.get_inp_comb(['r35tautau'])
cntplt.reshape()
cntplt.contcolor(ax,color='tab:pink')
cntplt.contline(ax,'tab:pink',ls='-',lw=1)
ax.text(200, 0.27, r'$h_S\rightarrow \tau \tau$', rotation=0, color='tab:pink', alpha=1)
ax.text(200, -0.3, r'$h_S\rightarrow \tau \tau$', rotation=-0, color='tab:pink', alpha=1)

cntplt.get_inp_comb(['r35gamgam'])
cntplt.reshape()
cntplt.contcolor(ax,color="tab:red")
cntplt.contline(ax,"tab:red",ls='-',lw=1)
ax.text(250, 0.5, r'$h_S\rightarrow \gamma\gamma$', rotation=0, color='tab:red', alpha=1)
ax.text(250, -0.5, r'$h_S\rightarrow \gamma\gamma$', rotation=-0, color='tab:red', alpha=1)


cntpltlow.get_inp_comb(['r35HH'])
cntpltlow.cut({'x':[62.5,130],'y':[]})
cntpltlow.reshape()
cntpltlow.contcolor(ax,color=g1)
cntpltlow.contline(ax,'tab:green',ls='-',lw=1)


ax.text(20, 0.05, r'$h\rightarrow h_S h_S$', rotation=0, color='tab:green', alpha=1)
ax.text(20, -0.05, r'$h_{125}$', rotation=0, color='tab:cyan', alpha=1)

cntpltlow.get_inp_comb(['hscheck'])
cntpltlow.reshape()
cntpltlow.contcolor(ax,color=c1)
cntpltlow.contline(ax,'tab:cyan',ls='-',lw=1)

cntpltlow.get_inp_comb(['r25tautau'])
cntpltlow.reshape()
cntpltlow.contcolor(ax,color='tab:pink')
cntpltlow.contline(ax,'tab:pink',ls='-',lw=1)

# ax.text(50, 0.5, r'$h_S\rightarrow   \tau\tau$', rotation=0, color='tab:red', alpha=1)
# ax.text(50, -0.5, r'$h_S\rightarrow  \tau\tau$', rotation=-0, color='tab:red', alpha=1)


ax.set_xscale('log')


ax.set_ylabel(r'$\alpha_{HS}$')
ax.set_xlabel(r'$m_{h_S}$ [GeV]')


plt.tight_layout()
plt.savefig('mhsa2.png', dpi=300)
# Out:
# ['Unnamed: 0', 'vs', 'mh1', 'mh2', 'mh3', 'ma1', 'ma2', 'mhp', 'mutild', 'rs25', 'rs35', 'rs45', 'rs36', 'r25VV', 'r25tautau', 'r35tautau', 'r25HH', 'r35HH', 'r45HH', 'r35ZH', 'r36ZH', 'STUFit', 'b->sgamma', 'bs->mumu', 'delmbs', 'bsgcheck', 'bsmmcheck', 'mbscheck', 'flavorcheck', 'r35gamgam']
# ['Unnamed: 0', 'vs', 'mh1', 'mh2', 'mh3', 'ma1', 'ma2', 'mhp', 'mutild', 'rs25', 'rs35', 'rs45', 'rs36', 'r25tautau', 'r25HH', 'r35HH', 'delchi2', 'hscheck', 'STUFit', 'b->sgamma', 'bs->mumu', 'delmbs', 'bsgcheck', 'bsmmcheck', 'mbscheck', 'flavorcheck', 'r25ZH', 'r36ZH', 'r35VV', 'r45HH']

# %% [markdown]
# #### $\alpha_{AS}$ vs $m_{AS}$

# %%
fig, ax = plt.subplots(1, 1)
cntplt = fplt.cntplt(
    50, 100,
    '../build/',
    'masa4',
    'ma2',
    'a4',
)

cntplt.printidx()

c = 'tab:cyan'
cntplt.get_inp_comb(['hscheck'])
cntplt.cut(cut={'x':[120,130],'y':[]},both=False)
cntplt.reshape()
cntplt.contcolor(ax,color=c, alp=0.3)
cntplt.contline(ax,c,ls='-',lw=1)
ax.text(30, 0.05, r'$h_{125}$', rotation=0, color=c, alpha=1)

c = 'tab:green'
cntplt.get_inp_comb(['r25HH'])
cntplt.cut(cut={'x':[63, 700],'y':[]},both=False)
cntplt.reshape()
cntplt.contcolor(ax,color=c, alp=0.3)
cntplt.contline(ax,c,ls='-',lw=1)
ax.text(30, -0.1, r'$h\rightarrow A_S A_S$', rotation=0, color=c, alpha=1)

c = 'tab:blue'
cntplt.get_inp_comb(['r36ZH'])
cntplt.reshape()
cntplt.contcolor(ax,color=c,alp=0.3)
cntplt.contline(ax,c,ls='-',lw=1)
ax.text(150, -0.1, r'$H\rightarrow A_S Z$', rotation=0, color=c, alpha=1)

c = 'tab:red'
cntplt.get_inp_comb(['r36tautau'])
cntplt.reshape()
cntplt.contcolor(ax,color=c,alp=0.3)
cntplt.contline(ax,c,ls='-',lw=1)
ax.text(170, -0.32, r'$A_S\rightarrow \tau\tau$', rotation=0, color=c, alpha=1)

c = 'tab:orange'
cntplt.get_inp_comb(['r36gamgam'])
cntplt.reshape()
cntplt.contcolor(ax,color=c,alp=0.3)
cntplt.contline(ax,c,ls='-',lw=1)
ax.text(200, -0.6, r'$A_S\rightarrow \gamma\gamma$', rotation=50, color=c, alpha=1)

c = 'tab:brown'
cntplt.get_inp_comb(['r46HH'])
cntplt.reshape()
cntplt.contcolor(ax,color=c)
cntplt.contline(ax,c,ls='-',lw=1)
ax.text(65, 0.1, r'$A\rightarrow A_S h $', rotation=00, color=c, alpha=1)

ax.set_xscale('log')


ax.set_ylabel(r'$\alpha_{AS}$')
ax.set_xlabel(r'$m_{A_S}$ [GeV]')


plt.tight_layout()
plt.savefig('masa4.png', dpi=300)
# Out:
# ['Unnamed: 0', 'vs', 'mh1', 'mh2', 'mh3', 'ma1', 'ma2', 'mhp', 'mutild', 'rs25', 'rs35', 'rs36', 'rs46', 'r36tautau', 'r25HH', 'r36HH', 'delchi2', 'hscheck', 'STUFit', 'b->sgamma', 'bs->mumu', 'delmbs', 'bsgcheck', 'bsmmcheck', 'mbscheck', 'flavorcheck', 'r35ZH', 'r36ZH', 'r25VV', 'r25gamgam', 'r25tautau', 'r46HH', 'r36gamgam']

# %% [markdown]
# ### $c_{\beta-\alpha}$ vs $m_H$
