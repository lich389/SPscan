# %%
import sys
import contourplt as fplt
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # $t_b$ vs $m_A$

# %%
fig, ax = plt.subplots(1, 1)
cntplt = fplt.cntplt(
    40, 40,
    '../build/',
    '',
    'ma1',
    'tb',
)

cntplt.get_inp_comb(['r36tttt', 'r35tttt'])
cntplt.cut(cut={'x':[],'y':[]})
cntplt.reshape()
cntplt.contline(ax,'tab:orange')
cntplt.contcolor(ax,'tab:orange')

cntplt.get_inp_comb(['r36tt', 'r35tt'])
cntplt.cut(cut={'x':[],'y':[]})
cntplt.reshape()
cntplt.contline(ax,'tab:green')
cntplt.contcolor(ax,'tab:green')


cntplt.get_inp_comb(['r36gamgam', 'r35gamgam'])
cntplt.reshape()
cntplt.contline(ax,'tab:blue')
cntplt.contcolor(ax,'tab:blue')

cntplt.get_inp_comb(['flavorcheck'])
cntplt.reshape()
cntplt.contline(ax,'tab:grey')
cntplt.contcolor(ax,'tab:grey')

cntplt.get_inp_comb(['r36tautau'])
cntplt.cut(cut={'x':[],'y':[]},both=False)
cntplt.reshape()
cntplt.contline(ax,'tab:red')
cntplt.contcolor(ax,'tab:red')


# ax.legend(cntplt.lst_lab)
# ax.set_xscale('log')
ax.set_yscale('log')

# %%
fig, ax = plt.subplots(1, 1)



fplt.inp.lst_lab=[]
fplt.inp.shape = (50, 50)
fplt.inp.flab = ''
fplt.inp.fpath = './'
# fplt.inp.flab = '.csv'
# fplt.inp.fpath = './'
fplt.inp.xlab = 'ma1'
fplt.inp.ylab = 'tb'

df = (fplt.inp.dfin)
numeric_cols = df.select_dtypes(include=[np.number]).columns
has_value_above_1 = (df[numeric_cols] > 1).any()
columns_with_values_above_1 = has_value_above_1[has_value_above_1].index.tolist()
print(columns_with_values_above_1)

fplt.inp.zlab = 'hscheck'
fplt.get_inp()
fplt.plt_contour(ax, plt.get_cmap('tab20')(1), alp=0.3, lab=False)
fplt.inp.zlab = 'STUcheck'
fplt.get_inp()
fplt.plt_contour(ax, plt.get_cmap('tab20')(8), alp=0.3, lab=r'$STU$')
fplt.inp.zlab = 'flavorcheck'
fplt.get_inp()
fplt.plt_conhatch(ax, r'Flavor' )

fplt.inp.zlab = 'rs35'
fplt.get_inp()
fplt.plt_contour(ax, plt.get_cmap('tab20')(5), alp=0.3, lab=r'$35$')

fplt.inp.zlab = 'rs45'
fplt.get_inp()
fplt.plt_contour(ax, plt.get_cmap('tab20')(6), alp=0.3, lab=r'$45$')

fplt.inp.zlab = 'rs36'
fplt.get_inp()
fplt.plt_contour(ax, plt.get_cmap('tab20')(8), alp=0.3, lab=r'$36$')
# fplt.inp.Z = np.reshape(fplt.comb(['r45tautau', 'r36tautau']) , fplt.inp.shape)
# fplt.plt_contour(ax, 'orange', alp=0.5,lab=r'$H/A\rightarrow \tau\tau$')

fplt.inp.Z = np.reshape(fplt.comb(['r45tttt', 'r36tttt']) , fplt.inp.shape)
fplt.plt_contour(ax, 'yellowgreen', alp=0.5,lab=r'$ttH/A\rightarrow tttt$')

fplt.inp.Z = np.reshape(fplt.comb(['r45tt', 'r36tt']) , fplt.inp.shape)
fplt.plt_contour(ax, 'green',alp=0.1, lab=r'$H/A\rightarrow tt$')


fplt.inp.Z = np.reshape(fplt.comb(['r45gamgam', 'r36gamgam']) , fplt.inp.shape)
fplt.plt_contour(ax, 'blue',alp=0.1, lab=r'$H/A\rightarrow \gamma\gamma$')

ax.set_yscale('log')
# ax.set_xscale('log')
# Out:
# []
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 21
#      18 print(columns_with_values_above_1)
#      20 fplt.inp.zlab = 'hscheck'
# ---> 21 fplt.get_inp()
#      22 fplt.plt_contour(ax, plt.get_cmap('tab20')(1), alp=0.3, lab=False)
#      23 fplt.inp.zlab = 'STUcheck'
#
# File ~/Documents/myscript/git/SPscan/plot/contourplt.py:100, in get_inp(cut)
#      98 def get_inp(cut = {}):
#      99     # data saving at inp.dfin
# --> 100     inp.dfin = pd.read_csv(inp.fpath+str(inp.shape)+inp.flab+'.csv')
#     103     xdf = (inp.dfin[inp.xlab])
#     104     ydf = (inp.dfin[inp.ylab])
#
# ...
